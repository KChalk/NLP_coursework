# %% [markdown]
# # Imports

# %%
from sklearn.manifold import TSNE
import seaborn as sns;
import matplotlib.pyplot as plt
from sklearn.preprocessing import Normalizer
import pandas as pd

dictionary={
        'gaming':set(['leagueoflegends', 'gaming', 'DestinyTheGame', 'DotA2', 'ContestofChampions', 'StarWarsBattlefront', 'Overwatch', 'WWII', 'hearthstone', 'wow', 'heroesofthestorm', 'destiny2', 'darksouls3', 'fallout']),
        'mental_health':set(['SuicideWatch', 'depression', 'OCD', 'dpdr', 'proED', 'Anxiety', 'BPD', 'socialanxiety', 'mentalhealth', 'ADHD', 'bipolar']),
        'computers':set(['buildapc', 'techsupport', 'buildapcforme', 'hacker', 'SuggestALaptop', 'hardwareswap', 'laptops', 'computers', 'pcmasterrace']),
        'relationships':set(['relationshps', 'relationship_advice', 'breakups', 'dating_advice', 'LongDistance', 'polyamory', 'wemetonline']),
        'drugs':set(['MDMA', 'Drugs', 'trees', 'opiates', 'LSD']),
        'general':set([ 'tifu', 'r4r', 'AskReddit', 'reddit.com', 'tipofmytongue', 'Life', 'Advice', 'jobs', 'teenagers', 'HomeImprovement', 'redditinreddit']),
        'sports':set(['FIFA', 'nba', 'hockey', 'nfl', 'mls', 'baseball']),
        'media':set(['BokuNoHeroAcademia', 'anime', 'movies', 'StrangerThings'])
}

def reset_input():
    med=pd.read_csv('../Spark/coll_freqs_16-05.csv', header=None,  index_col=0)
    med_nums=med.iloc[:,1:]
    med_norm=norm.transform(med_nums.T).T
    return med, med_nums, med_norm

# %% [markdown]
# # Normalized
#
# Iterations: 2000
# Perplexity: 50

# %%
norm = Normalizer()
model=TSNE(n_iter=2000, perplexity=50.0)

med, med_nums, med_norm = reset_input()

twod=model.fit_transform(med_norm)

med['Tsne1']=twod[:,0]
med['Tsne2']=twod[:,1]
med['category']=''

for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c
        
fig,ax=plt.subplots(figsize=(10,6))
sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', hue='category', data=med, s= 100)

# %% [markdown]
# Iter: 2000
# Perplexity: 30

# %%
norm = Normalizer()
med, med_nums, med_norm = reset_input()

model=TSNE(n_iter=2000, perplexity=30.0)
twod=model.fit_transform(med_norm)

med['Tsne1']=twod[:,0]
med['Tsne2']=twod[:,1]
med['category']=''

for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c
        
fig,ax=plt.subplots(figsize=(10,6))
sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', hue='category', data=med, s= 100).set_title("TSNE I:2000, P:30")
# Out:
# Text(0.5, 1.0, 'TSNE I:2000, P:30')

# %% [markdown]
# Iter: 2000
# Perplexity: 20

# %%
norm = Normalizer()
med, med_nums, med_norm = reset_input()

model=TSNE(n_iter=2000, perplexity=20.0)
twod=model.fit_transform(med_norm)

med['Tsne1']=twod[:,0]
med['Tsne2']=twod[:,1]
med['category']=''

for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c
        
fig,ax=plt.subplots(figsize=(10,6))
sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', hue='category', data=med, s= 100).set_title("TSNE I:2000, P:20")
# Out:
# Text(0.5, 1.0, 'TSNE I:2000, P:20')

# %%
norm = Normalizer()
med, med_nums, med_norm = reset_input()

model=TSNE(n_iter=2000, perplexity=5.0)
twod=model.fit_transform(med_norm)

med['Tsne1']=twod[:,0]
med['Tsne2']=twod[:,1]
med['category']=''

for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c
        
fig,ax=plt.subplots(figsize=(10,6))
sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', hue='category', data=med, s= 100).set_title("TSNE I:2000, P:5")
# Out:
# Text(0.5, 1.0, 'TSNE I:2000, P:5')

# %%
norm = Normalizer()
med, med_nums, med_norm = reset_input()

model=TSNE(n_iter=2000, perplexity=5.0)
twod=model.fit_transform(med_norm)


med['Tsne1']=twod[:,0]
med['Tsne2']=twod[:,1]
med['category']=''

for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c

        
cats=['sports','gaming','relationships','drugs','computers','mental_health']
med=med[med.category.isin(cats)].dropna()

fig,ax=plt.subplots(figsize=(10,6))
sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', hue='category', data=med, s= 100).set_title("TSNE I:2000, P:5")
# Out:
# Text(0.5, 1.0, 'TSNE I:2000, P:5')

# %%
norm = Normalizer()
med, med_nums, med_norm = reset_input()

model=TSNE(n_iter=2000, perplexity=5.0)
twod=model.fit_transform(med_norm)


med['Tsne1']=twod[:,0]
med['Tsne2']=twod[:,1]
med['category']=''

for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c

        
cats=['sports','gaming','relationships','drugs','computers','mental_health']
med=med[med.category.isin(cats)].dropna()

fig,ax=plt.subplots(figsize=(10,6))
fig=sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', hue='category', data=med, s= 100)
fig.set_title("TSNE I:2000, P:5")

for line in range(0,med.shape[0]):
     fig.text(med.Tsne1[line]+0.01, med.Tsne2[line], 
     med.index[line], horizontalalignment='left', 
     size='medium', color='black', weight='normal')

# %%
norm = Normalizer()
med, med_nums, med_norm = reset_input()

model=TSNE(n_iter=2000, perplexity=5.0)
twod=model.fit_transform(med_norm)

med['Tsne1']=twod[:,0]
med['Tsne2']=twod[:,1]
med['category']=''

for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c
med=med.dropna()
        
fig,ax=plt.subplots(figsize=(10,10))
fig=sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', hue='category', data=med, s= 100)
fig.set_title("TSNE I:2000, P:5")

for line in range(0,med.shape[0]):
     fig.text(med.Tsne1[line]+0.01, med.Tsne2[line], 
     med.index[line], horizontalalignment='left', 
     size='medium', color='black', weight='normal')

# %% [markdown]
# # Embeddings

# %%
pre_class=pd.read_csv('digression/embedding_weights_preClass_bi.csv',index_col='char')
pre_class['cons']=False

consonants=['<BOS>','<EOS>','B','CH','D','DH','F','G','HH','K','L','M','N','NG','P','SH','R','S','T','TH','V','W','Y','Z','ZH']

for con in consonants:
    pre_class.loc[con,'cons']=True
    
pre_class_cons=pre_class[pre_class.cons].dropna()
pre_class_vow=pre_class[pre_class.cons.isin([False])].dropna()

# %%
model=TSNE(n_iter=10000, perplexity=55.0)
twod=model.fit_transform(pre_class.iloc[:,1:-1])

tsne=pd.DataFrame()
tsne['Tsne1']=twod[:,0]
tsne['Tsne2']=twod[:,1]
tsne['char']=pre_class.index
tsne=tsne.set_index('char')
tsne['cons']=pre_class.loc[:,'cons']
fig,ax=plt.subplots(figsize=(10,10))
fig=sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', hue='cons',data=tsne, s= 50)
fig.set_title("TSNE I:10000, P:55")

for line in range(0,tsne.shape[0]):
     fig.text(tsne.Tsne1[line]+0.01, tsne.Tsne2[line], 
     tsne.index[line], horizontalalignment='left', 
     size='medium', color='black', weight='normal')

# %%
model=TSNE(n_iter=5000, perplexity=10.0)
twod=model.fit_transform(pre_class_cons.iloc[:,1:-1])

tsne=pd.DataFrame()
tsne['Tsne1']=twod[:,0]
tsne['Tsne2']=twod[:,1]
tsne['char']=pre_class_cons.index
tsne=tsne.set_index('char')
tsne['cons']=pre_class_cons.loc[:,'cons']

fig,ax=plt.subplots(figsize=(10,10))
fig=sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', data=tsne, s= 50)
fig.set_title("TSNE I:2000, P:25")

for line in range(0,tsne.shape[0]):
     fig.text(tsne.Tsne1[line]+0.03, tsne.Tsne2[line]+0.03, 
     tsne.index[line], horizontalalignment='left', 
     size='large', color='black', weight='normal')

# %%
model=TSNE(n_iter=5000, perplexity=5.0)
twod=model.fit_transform(pre_class_vow.iloc[:,1:-1])

tsne=pd.DataFrame()
tsne['Tsne1']=twod[:,0]
tsne['Tsne2']=twod[:,1]
tsne['char']=pre_class_vow.index
tsne=tsne.set_index('char')
tsne['cons']=pre_class_vow.loc[:,'cons']

fig,ax=plt.subplots(figsize=(10,10))
fig=sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', data=tsne, s= 50)
fig.set_title("TSNE I:2000, P:25")

for line in range(0,tsne.shape[0]):
     fig.text(tsne.Tsne1[line]+0.01, tsne.Tsne2[line], 
     tsne.index[line], horizontalalignment='left', 
     size='medium', color='black', weight='normal')

# %%
pre_class=pd.read_csv('digression/embedding_weights_preClass.csv')
pre_class

model=TSNE(n_iter=5000, perplexity=20.0)
twod=model.fit_transform(pre_class.iloc[:,:-1])

tsne=pd.DataFrame()
tsne['Tsne1']=twod[:,0]
tsne['Tsne2']=twod[:,1]
tsne['char']=pre_class.char

fig,ax=plt.subplots(figsize=(10,10))
fig=sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', data=tsne, s= 50)
fig.set_title("TSNE I:2000, P:25")

for line in range(0,tsne.shape[0]):
     fig.text(tsne.Tsne1[line]+0.01, tsne.Tsne2[line], 
     tsne.char[line], horizontalalignment='left', 
     size='medium', color='black', weight='normal')

# %%
phon_class=pd.read_csv('digression/embedding_weights_phonClass.csv')

model=TSNE(n_iter=5000, perplexity=20.0)
twod=model.fit_transform(phon_class.iloc[:,:-1])

tsne=pd.DataFrame()
tsne['Tsne1']=twod[:,0]
tsne['Tsne2']=twod[:,1]
tsne['char']=phon_class.char

fig,ax=plt.subplots(figsize=(10,10))
fig=sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', data=tsne, s= 20)
fig.set_title("TSNE I:2000, P:25")

for line in range(0,tsne.shape[0]):
     fig.text(tsne.Tsne1[line]+0.01, tsne.Tsne2[line], 
     tsne.char[line], horizontalalignment='left', 
     size='medium', color='black', weight='normal')

# %%
class_embd=pd.read_csv('digression/embedding_weights_2Class.csv')

model=TSNE(n_iter=5000, perplexity=5.0)
twod=model.fit_transform(class_embd.iloc[:,:-1])

tsne=pd.DataFrame()
tsne['Tsne1']=twod[:,0]
tsne['Tsne2']=twod[:,1]
tsne['char']=class_embd.char

fig,ax=plt.subplots(figsize=(10,10))
fig=sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', data=tsne, s= 20)
fig.set_title("TSNE I:2000, P:25")

for line in range(0,tsne.shape[0]):
     fig.text(tsne.Tsne1[line]+0.01, tsne.Tsne2[line], 
     tsne.char[line], horizontalalignment='left', 
     size='medium', color='black', weight='normal')

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
PCS=pca.fit_transform(med_nums)

med, med_nums, med_norm = reset_input()

med['PC1']=PCS[:,0]
med['PC2']=PCS[:,1]
med['category']=''

for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c
        
fig,ax=plt.subplots(figsize=(10,6))
sns.scatterplot(ax=ax,x='PC1', y='PC2', hue='category', data=med, s= 100)

# %%
med, med_nums, med_norm = reset_input()

from sklearn.decomposition import PCA
pca = PCA(n_components=2)
PCS=pca.fit_transform(med_norm)


med['PC1']=PCS[:,0]
med['PC2']=PCS[:,1]
med['category']=''

for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c
        
fig,ax=plt.subplots(figsize=(10,6))
sns.scatterplot(ax=ax,x='PC1', y='PC2', hue='category', data=med, s= 100).set_title("Normalized PCA")
# Out:
# Text(0.5, 1.0, 'Normalized PCA')

# %% [markdown]
# # GGplot

# %%
''' Did not work
import rpy2.robjects.lib.ggplot2 as gg2
import rpy2.robjects as ro

norm = Normalizer()
med, med_nums, med_norm = reset_input()

model=TSNE(n_iter=2000, perplexity=5.0)
twod=model.fit_transform(med_norm)


med['Tsne1']=twod[:,0]
med['Tsne2']=twod[:,1]
med['category']=''

for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c

        
cats=['sports','gaming','relationships','drugs','computers','mental_health']
med=med[med.category.isin(cats)].dropna()

med.to_csv('ggplot.csv')

df=ro.DataFrame({})
df.from_csvfile('ggplot.csv')

gp=gg2.ggplot(df)

pp = gp + \
    gg2.aes_string(x='Tsne1', y='Tsne2') +\
    gg2.geom_point()

pp.plot()

'''
# Out:
# " Did not work\nimport rpy2.robjects.lib.ggplot2 as gg2\nimport rpy2.robjects as ro\n\nnorm = Normalizer()\nmed, med_nums, med_norm = reset_input()\n\nmodel=TSNE(n_iter=2000, perplexity=5.0)\ntwod=model.fit_transform(med_norm)\n\n\nmed['Tsne1']=twod[:,0]\nmed['Tsne2']=twod[:,1]\nmed['category']=''\n\nfor c, subs in dictionary.items():\n    for s in subs:\n        med.loc[s,'category']=c\n\n        \ncats=['sports','gaming','relationships','drugs','computers','mental_health']\nmed=med[med.category.isin(cats)].dropna()\n\nmed.to_csv('ggplot.csv')\n\ndf=ro.DataFrame({})\ndf.from_csvfile('ggplot.csv')\n\ngp=gg2.ggplot(df)\n\npp = gp +     gg2.aes_string(x='Tsne1', y='Tsne2') +    gg2.geom_point()\n\npp.plot()\n\n"

# %% [markdown]
# # Disappointment

# %%
norm = Normalizer()
med, med_nums, med_norm = reset_input()

model=TSNE(n_iter=2000, perplexity=30.0)
twod=model.fit_transform(med_nums)

med['Tsne1']=twod[:,0]
med['Tsne2']=twod[:,1]
med['category']=''

for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c
        
fig,ax=plt.subplots(figsize=(10,6))
sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', hue='category', data=med, s= 100).set_title("TSNE I:2000, P:30")
# Out:
# Text(0.5, 1.0, 'TSNE I:2000, P:30')

# %%
norm = Normalizer()
med, med_nums, med_norm = reset_input()

model=TSNE(n_iter=2000, perplexity=50.0)
twod=model.fit_transform(med_nums)

med['Tsne1']=twod[:,0]
med['Tsne2']=twod[:,1]
med['category']=''

for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c
        
fig,ax=plt.subplots(figsize=(10,6))
sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', hue='category', data=med, s= 100).set_title("TSNE I:2000, P:50")
# Out:
# Text(0.5, 1.0, 'TSNE I:2000, P:50')

# %%
norm = Normalizer()
med, med_nums, med_norm = reset_input()

model=TSNE(n_iter=5000, perplexity=30.0)
twod=model.fit_transform(med_nums)

med['Tsne1']=twod[:,0]
med['Tsne2']=twod[:,1]
med['category']=''

for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c
        
fig,ax=plt.subplots(figsize=(10,6))
sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', hue='category', data=med, s= 100).set_title("TSNE I:5000, P:30")
# Out:
# Text(0.5, 1.0, 'TSNE I:5000, P:30')

# %%
norm = Normalizer()
med, med_nums, med_norm = reset_input()

model=TSNE(n_iter=2000, perplexity=15.0)
twod=model.fit_transform(med_nums)

med['Tsne1']=twod[:,0]
med['Tsne2']=twod[:,1]
med['category']=''

for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c
        
fig,ax=plt.subplots(figsize=(10,6))
sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', hue='category', data=med, s= 100).set_title("TSNE I:2000, P:15")
# Out:
# Text(0.5, 1.0, 'TSNE I:2000, P:15')

# %%
med=pd.read_csv('../Spark/coll_freqs_16-05.csv', header=None,  index_col=0)
med_nums=med.iloc[:,1:]

model=TSNE(n_iter=2000, perplexity=15.0, verbose=0)

twod=model.fit_transform(med_nums)

med['Tsne1']=twod[:,0]
med['Tsne2']=twod[:,1]
med['category']=''

for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c
        
fig,ax=plt.subplots(figsize=(10,6))
sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', hue='category', data=med, s= 100)

# %%
med=pd.read_csv('../Spark/coll_freqs_16-05.csv', header=None,  index_col=0)
med_nums=med.iloc[:,1:]

model=TSNE(n_iter=5000, perplexity=10.0, verbose=1)

twod=model.fit_transform(med_nums)

med['Tsne1']=twod[:,0]
med['Tsne2']=twod[:,1]
med['category']=''

for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c
        
fig,ax=plt.subplots(figsize=(10,6))
sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', hue='category', data=med, s= 100)
# Out:
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 51 samples in 0.000s...
# [t-SNE] Computed neighbors for 51 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 51 / 51
# [t-SNE] Mean sigma: 43481.634560
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 56.827522
# [t-SNE] Error after 1100 iterations: 0.104560

# %% [markdown]
# # Subests?

# %%
med=pd.read_csv('../Spark/coll_freqs_16-05.csv', header=None,  index_col=0)
med['category']=''
for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c

cats=['mental_health','general','sports']
med=med[med.category.isin(cats)].dropna()

med_nums=med.iloc[:,1:-1]

model=TSNE(n_iter=5000, perplexity=10.0)

twod=model.fit_transform(med_nums)

med['Tsne1']=twod[:,0]
med['Tsne2']=twod[:,1]


        
fig,ax=plt.subplots(figsize=(10,6))
sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', hue='category', data=med, s= 100)

# %%
med=pd.read_csv('../Spark/coll_freqs_16-05.csv', header=None,  index_col=0)
med['category']=''
for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c

cats=['gaming','general','sports']
med=med[med.category.isin(cats)].dropna()

med_nums=med.iloc[:,1:-1]

model=TSNE(n_iter=5000, perplexity=10.0)

twod=model.fit_transform(med_nums)

med['Tsne1']=twod[:,0]
med['Tsne2']=twod[:,1]


        
fig,ax=plt.subplots(figsize=(10,6))
sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', hue='category', data=med, s= 100)

# %%
med=pd.read_csv('../Spark/coll_freqs_16-05.csv', header=None,  index_col=0)
med['category']=''
for c, subs in dictionary.items():
    for s in subs:
        med.loc[s,'category']=c

cats=['mental_health','relationships','general']
med=med[med.category.isin(cats)].dropna()

med_nums=med.iloc[:,1:-1]

model=TSNE(n_iter=5000, perplexity=10.0)

twod=model.fit_transform(med_nums)

med['Tsne1']=twod[:,0]
med['Tsne2']=twod[:,1]


        
fig,ax=plt.subplots(figsize=(10,6))
sns.scatterplot(ax=ax,x='Tsne1', y='Tsne2', hue='category', data=med, s= 100)
